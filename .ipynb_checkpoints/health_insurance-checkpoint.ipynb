# %% [markdown]
# # 0.0 Configurações iniciais

# %% [markdown]
# ## 0.1 Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sweetviz as sv
import xgboost as xgb
import pickle

import inflection
import warnings
import random

from matplotlib import pyplot as plt

from IPython.display import Image
from IPython.core.display import HTML

from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler, MinMaxScaler, LabelEncoder, StandardScaler

from sklearn import model_selection as ms
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model as lm
from sklearn import metrics as mt

import scikitplot as skplt

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 0.2 Funções auxiliares

# %%
def jupyter_settings():
    # %matplotlib inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [24, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:75% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
    
jupyter_settings()

# def standardization(x):
#     if isinstance(x, (int, float, np.number)):
#         return (x - df4['annual_premium'].mean()) / df4['annual_premium'].std()
#     else:
#         return x
    
# def minmaxscaler_age(x):
#     if isinstance(x, (int, float, np.number)):
#         return (x - df4['age'].min()) / (df4['age'].max() - df4['age'].min())
#     else:
#         return x
    
# def minmaxscaler_vintage(x):
#     if isinstance(x, (int, float, np.number)):
#         return (x - df4['vintage'].min()) / (df4['vintage'].max() - df4['vintage'].min())
#     else:
#         return x

def precision_top_k(data, k = 2000, target = 'response'):
    
    data = data.reset_index(drop = True)
    
    data['ranking'] = data.index + 1
    
    # cumsum = soma acumulada até posição 'k'
    data['precision_at_k'] = data[target].cumsum()/data['ranking']
    
    return data.loc[k, 'precision_at_k']

def recall_top_k(data, k = 2000, target = 'response'):
    
    data = data.reset_index(drop = True)
    
    data['ranking'] = data.index + 1
    
    # cumsum = soma acumulada até a posição 'k'
    data['recall_at_k'] = data[target].cumsum()/data[target].sum()
    
    return data.loc[k, 'recall_at_k']

def cross_validation(x_train, y_train, x_val, y_val, kfold, model, verbose = False):
    
    # colunas selecionadas (>2% de importância):
    cols_selected_mdi = ['vintage', 'annual_premium', 'age', 'region_code', 'vehicle_damage', 'policy_sales_channel', 'previously_insured']

    # juntando treino e validação após preparados os dados
    df_train = x_train.copy()
    df_train['response'] = y_train.copy()
    df_val = x_val.copy()
    df_val['response'] = y_val.copy()
    df_model = pd.concat([df_train, df_val])
    
    # listas de precision e recall contendo cada iteração do cross-validation
    precision_top_k_list = []
    recall_top_k_list = []
    
    for k in range(1, kfold+1):
        if verbose:
            print('\nKFold Number: {}'.format(k))
            
        # modelagem
        x = df_model.drop(['response'], axis = 1)
        y = df_model['response']
        
        # separação em treino e validação
        x_train, x_val, y_train, y_val = ms.train_test_split(x, y, test_size = 0.2) # retirar o random_state para pegar valores diferentes em cada iteração
        
        # seleção de colunas para o treino
        x_train_select = x_train[cols_selected_mdi]
        x_val_select = x_val[cols_selected_mdi]
            
        # treino
        m = model.fit(x_train_select, y_train)

        # predição
        yhat_val = m.predict_proba(x_val_select)
        
        # performance
        df_test = x_val.copy()
        df_test['response'] = y_val.copy()
        
        # propensão de compra
        df_test['score'] = yhat_val[:,1].tolist()

        # ordenação
        df_test = df_test.sort_values(by = 'score', ascending = False)

        # performance
        precision_at_k = precision_top_k(df_test)
        recall_at_k = recall_top_k(df_test)
        
        # performance para cada interação (kfold)
        precision_top_k_list.append(precision_at_k)
        recall_top_k_list.append(recall_at_k)
        
        print(f'Precision Top K: {np.round(precision_at_k, 4)}, Recall Top K: {np.round(recall_at_k, 4)}')    
    
    print(f'\nPrecisão Top K Média: {np.average(precision_top_k_list)}, Recall Top K Média: {np.average(recall_top_k_list)}\n')

    return df_test
# Out:
# <style>.container { width:75% !important; }</style>

# %% [markdown]
# # 1.0 Coleta dos dados

# %% [markdown]
# ## 1.1 Leitura dos dados

# %%
df1 = pd.read_csv('data/train.csv')

# %% [markdown]
# ## 1.2 Visão geral dos dados

# %%
print('Os nomes das colunas são: \n{}\n'.format(df1.columns))
print('As colunas e os tipos do conjunto de dados são: \n{}\n'.format(df1.dtypes))
print('O tamanho do conjunto de dados é (linhas, colunas): \n{}\n'.format(df1.shape))
print('A quantidade de linhas vazias para cada coluna é: \n{}\n'.format(df1.isna().sum()))
# Out:
# Os nomes das colunas são:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')
#
# As colunas e os tipos do conjunto de dados são:
# id                        int64
# Gender                   object
# Age                       int64
# Driving_License           int64
# Region_Code             float64
# Previously_Insured        int64
# Vehicle_Age              object
# Vehicle_Damage           object
# Annual_Premium          float64
# Policy_Sales_Channel    float64
# Vintage                   int64
# Response                  int64
# dtype: object
#
# O tamanho do conjunto de dados é (linhas, colunas):
# (381109, 12)
#
# A quantidade de linhas vazias para cada coluna é:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
df1.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0   1    Male   44                1         28.0                   0   > 2 Years            Yes         40454.0                  26.0      217         1
# 1   2    Male   76                1          3.0                   0    1-2 Year             No         33536.0                  26.0      183         0
# 2   3    Male   47                1         28.0                   0   > 2 Years            Yes         38294.0                  26.0       27         1
# 3   4    Male   21                1         11.0                   1    < 1 Year             No         28619.0                 152.0      203         0
# 4   5  Female   29                1         41.0                   1    < 1 Year             No         27496.0                 152.0       39         0

# %% [markdown]
# # 2.0 Descrição dos dados

# %% [markdown]
# ## 2.1 Renomeando colunas

# %%
df2 = df1.copy()

cols_old = ['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
       'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
       'Policy_Sales_Channel', 'Vintage', 'Response']

snakecase = lambda x: inflection.underscore(x)
cols_new = list(map(snakecase, cols_old))
df2.columns = cols_new

print('Os nomes das colunas são: \n{}\n'.format(df2.columns))
# Out:
# Os nomes das colunas são:
# Index(['id', 'gender', 'age', 'driving_license', 'region_code',
#        'previously_insured', 'vehicle_age', 'vehicle_damage', 'annual_premium',
#        'policy_sales_channel', 'vintage', 'response'],
#       dtype='object')

# %% [markdown]
# ## 2.2 Alterando tipos dos dados

# %%
# alterando dados float64 para diminuir o tamanho do dataset
df2['region_code'] = df2['region_code'].astype('int64')
df2['policy_sales_channel'] = df2['policy_sales_channel'].astype('int64')
df2['annual_premium'] = df2['annual_premium'].astype('float32')

# transformando atributos categóricos em numéricos
df2['gender'] = df2['gender'].apply(lambda x: 0 if x == 'Female' else 1)
df2['vehicle_damage'] = df2['vehicle_damage'].apply(lambda x: 0 if x == 'No' else 1)
df2['vehicle_age'] = df2['vehicle_age'].apply(lambda x: 1 if (x == '< 1 Year') else 
                                                      2 if (x == '1-2 Year') else 
                                                      3 if (x == '> 2 Years') else x)

print('As colunas e os tipos do conjunto de dados são: \n{}\n'.format(df2.dtypes))
# Out:
# As colunas e os tipos do conjunto de dados são:
# id                        int64
# gender                    int64
# age                       int64
# driving_license           int64
# region_code               int64
# previously_insured        int64
# vehicle_age               int64
# vehicle_damage            int64
# annual_premium          float32
# policy_sales_channel      int64
# vintage                   int64
# response                  int64
# dtype: object

# %% [markdown]
# ## 2.3 Estatística descritiva

# %%
# atributos numéricos
num_attributes = df2.select_dtypes(include=['int64', 'float32'])

# atributos categóricos
cat_attributes = df2.select_dtypes(exclude=['int64', 'float32'])

# dropando id
num_attributes = num_attributes.drop(['id'], axis = 1)

# tendência central - mean, meadina 
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# dispersão - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_attributes.apply(np.std)).T 
d2 = pd.DataFrame(num_attributes.apply(min)).T 
d3 = pd.DataFrame(num_attributes.apply(max)).T 
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T 
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T 
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T 

# concatenar
m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']

m
# Out:
#               attributes     min       max     range          mean   median           std       skew    kurtosis
# 0                 gender     0.0       1.0       1.0      0.540761      1.0      0.498336  -0.163590   -1.973249
# 1                    age    20.0      85.0      65.0     38.822584     36.0     15.511591   0.672539   -0.565655
# 2        driving_license     0.0       1.0       1.0      0.997869      1.0      0.046109 -21.595182  464.354302
# 3            region_code     0.0      52.0      52.0     26.388807     28.0     13.229871  -0.115266   -0.867857
# 4     previously_insured     0.0       1.0       1.0      0.458210      0.0      0.498251   0.167747   -1.971871
# 5            vehicle_age     1.0       3.0       2.0      1.609616      2.0      0.567439   0.252896   -0.792253
# 6         vehicle_damage     0.0       1.0       1.0      0.504877      1.0      0.499976  -0.019507   -1.999630
# 7         annual_premium  2630.0  540165.0  537535.0  30577.921875  31669.0  17207.476562   1.766088   34.004574
# 8   policy_sales_channel     1.0     163.0     162.0    112.034295    133.0     54.203924  -0.900008   -0.970810
# 9                vintage    10.0     299.0     289.0    154.347397    154.0     83.671194   0.003030   -1.200688
# 10              response     0.0       1.0       1.0      0.122563      0.0      0.327935   2.301906    3.298788

# %% [markdown]
# # 3.0 Análise exploratória dos dados

# %% [markdown]
# ## 3.1 Análise univariada

# %%
df3 = df2.copy()

# tabela para melhor visualização de atributos com menos valores distintos
count_distinct = df3.drop(['id'], axis = 1)

for i in count_distinct.columns:
    count_distinct = df3[i].value_counts()
    count_distinct = pd.DataFrame({i: count_distinct.index, 'count': count_distinct.values})
    print('{}\n'.format(count_distinct.head()))
    # gender = 0 -> female
# Out:
#    gender   count
# 0       1  206089
# 1       0  175020
#
#    age  count
# 0   24  25960
# 1   23  24256
# 2   22  20964
# 3   25  20636
# 4   21  16457
#
#    driving_license   count
# 0                1  380297
# 1                0     812
#
#    region_code   count
# 0           28  106415
# 1            8   33877
# 2           46   19749
# 3           41   18263
# 4           15   13308
#
#    previously_insured   count
# 0                   0  206481
# 1                   1  174628
#
#    vehicle_age   count
# 0            2  200316
# 1            1  164786
# 2            3   16007
#
#    vehicle_damage   count
# 0               1  192413
# 1               0  188696
#
#    annual_premium  count
# 0          2630.0  64877
# 1         69856.0    140
# 2         39008.0     41
# 3         38287.0     38
# 4         45179.0     38
#
#    policy_sales_channel   count
# 0                   152  134784
# 1                    26   79700
# 2                   124   73995
# 3                   160   21779
# 4                   156   10661
#
#    vintage  count
# 0      256   1418
# 1       73   1410
# 2      282   1397
# 3      158   1394
# 4      187   1392
#
#    response   count
# 0         0  334399
# 1         1   46710

# %%
# plot para melhor visualização de atributos com mais valores distintos
count_distinct = df3[['age', 'region_code', 'annual_premium', 'policy_sales_channel', 'vintage']]

for i in count_distinct.columns:
    count_distinct = df3[i].value_counts()
    count_distinct = pd.DataFrame({i: count_distinct.index, 'count': count_distinct.values})
    plt.figure(figsize=(30, 10))
    plt.subplot(3, 2, 1)
    plt.scatter(x = count_distinct.iloc[:,0], y = count_distinct.iloc[:,1])
    plt.title('Count of distinct values for {}'.format(i))
    plt.xlabel(i)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# ## 3.2 Análise bivariada - Contagem

# %%
# tabela para melhor visualização de atributos com menos valores distintos - contagem
dist_resp = df3.drop(['id', 'response'], axis = 1)

for i in dist_resp.columns:
    dist_resp = pd.crosstab(df3[i], df3['response'])
    # o parâmetro 'normalize' que normaliza as colunas proporcionalmente de acordo com a contagens de linhas = 0 e de linhas = 1
    print(f'A coluna {i} tem a seguinte contagem de interesse: \n{dist_resp.head()}\n')
    # gender = 0 -> female
# Out:
# A coluna gender tem a seguinte contagem de interesse:
# response       0      1
# gender
# 0         156835  18185
# 1         177564  28525
#
# A coluna age tem a seguinte contagem de interesse:
# response      0    1
# age
# 20         6061  171
# 21        15883  574
# 22        20201  763
# 23        23364  892
# 24        25047  913
#
# A coluna driving_license tem a seguinte contagem de interesse:
# response              0      1
# driving_license
# 0                   771     41
# 1                333628  46669
#
# A coluna region_code tem a seguinte contagem de interesse:
# response        0     1
# region_code
# 0            1847   174
# 1             899   109
# 2            3751   287
# 3            8070  1181
# 4            1516   285
#
# A coluna previously_insured tem a seguinte contagem de interesse:
# response                 0      1
# previously_insured
# 0                   159929  46552
# 1                   174470    158
#
# A coluna vehicle_age tem a seguinte contagem de interesse:
# response          0      1
# vehicle_age
# 1            157584   7202
# 2            165510  34806
# 3             11305   4702
#
# A coluna vehicle_damage tem a seguinte contagem de interesse:
# response             0      1
# vehicle_damage
# 0               187714    982
# 1               146685  45728
#
# A coluna annual_premium tem a seguinte contagem de interesse:
# response            0     1
# annual_premium
# 2630.0          56372  8505
# 6098.0              1     0
# 7670.0              1     0
# 8739.0              1     0
# 9792.0              1     0
#
# A coluna policy_sales_channel tem a seguinte contagem de interesse:
# response                 0    1
# policy_sales_channel
# 1                     1039   35
# 2                        3    1
# 3                      364  159
# 4                      407  102
# 6                        3    0
#
# A coluna vintage tem a seguinte contagem de interesse:
# response     0    1
# vintage
# 10        1164  147
# 11        1153  191
# 12        1092  165
# 13        1145  184
# 14        1104  156

# %%
# plot para melhor visualização de atributos com mais valores distintos - contagem
dist_resp = df3[['age', 'region_code', 'annual_premium', 'policy_sales_channel', 'vintage']]

for i in dist_resp.columns:
    dist_resp = pd.crosstab(df3[i], df3['response'])
    dist_resp = dist_resp.reset_index()
    plt.figure(figsize=(30, 10))
    plt.subplot(3, 2, 1)
    plt.scatter(x = dist_resp.iloc[:,0], y = dist_resp.iloc[:,2], label = 'Tem interesse')
    plt.scatter(x = dist_resp.iloc[:,0], y = dist_resp.iloc[:,1], label = 'Não tem interesse')
    plt.title('Count of interested parties by {}'.format(i))
    plt.xlabel(i)
    plt.ylabel('Count of interested parties')
    plt.legend()
    plt.show()

# %% [markdown]
# ## 3.3 Análise bivariada - Proporção de interesse

# %%
# tabela para melhor visualização de atributos com menos valores distintos - proporção de interesse
dist_resp = df3.drop(['id', 'response'], axis = 1)

for i in dist_resp.columns:
    dist_resp = pd.crosstab(df3[i], df3['response'], normalize = 'index')
    # o parâmetro 'normalize' que normaliza as colunas proporcionalmente de acordo com a contagens de linhas = 0 e de linhas = 1
    print(f'A coluna {i} tem a seguinte proporção de interesse: \n{dist_resp.head()}\n')
    # gender = 0 -> female
# Out:
# A coluna gender tem a seguinte proporção de interesse:
# response         0         1
# gender
# 0         0.896098  0.103902
# 1         0.861589  0.138411
#
# A coluna age tem a seguinte proporção de interesse:
# response         0         1
# age
# 20        0.972561  0.027439
# 21        0.965121  0.034879
# 22        0.963604  0.036396
# 23        0.963226  0.036774
# 24        0.964831  0.035169
#
# A coluna driving_license tem a seguinte proporção de interesse:
# response                0         1
# driving_license
# 0                0.949507  0.050493
# 1                0.877283  0.122717
#
# A coluna region_code tem a seguinte proporção de interesse:
# response            0         1
# region_code
# 0            0.913904  0.086096
# 1            0.891865  0.108135
# 2            0.928925  0.071075
# 3            0.872338  0.127662
# 4            0.841755  0.158245
#
# A coluna previously_insured tem a seguinte proporção de interesse:
# response                   0         1
# previously_insured
# 0                   0.774546  0.225454
# 1                   0.999095  0.000905
#
# A coluna vehicle_age tem a seguinte proporção de interesse:
# response            0         1
# vehicle_age
# 1            0.956295  0.043705
# 2            0.826245  0.173755
# 3            0.706254  0.293746
#
# A coluna vehicle_damage tem a seguinte proporção de interesse:
# response               0         1
# vehicle_damage
# 0               0.994796  0.005204
# 1               0.762345  0.237655
#
# A coluna annual_premium tem a seguinte proporção de interesse:
# response               0         1
# annual_premium
# 2630.0          0.868906  0.131094
# 6098.0          1.000000  0.000000
# 7670.0          1.000000  0.000000
# 8739.0          1.000000  0.000000
# 9792.0          1.000000  0.000000
#
# A coluna policy_sales_channel tem a seguinte proporção de interesse:
# response                     0         1
# policy_sales_channel
# 1                     0.967412  0.032588
# 2                     0.750000  0.250000
# 3                     0.695985  0.304015
# 4                     0.799607  0.200393
# 6                     1.000000  0.000000
#
# A coluna vintage tem a seguinte proporção de interesse:
# response         0         1
# vintage
# 10        0.887872  0.112128
# 11        0.857887  0.142113
# 12        0.868735  0.131265
# 13        0.861550  0.138450
# 14        0.876190  0.123810

# %%
# plot para melhor visualização de atributos com mais valores distintos - porcentagem de interessados
dist_resp = df3[['age', 'region_code', 'annual_premium', 'policy_sales_channel', 'vintage']]

for i in dist_resp.columns:
    dist_resp = pd.crosstab(df3[i], df3['response'], normalize = 'index')
    dist_resp = dist_resp.reset_index()
    plt.figure(figsize=(30, 10))
    plt.subplot(3, 2, 1)
    plt.scatter(x = dist_resp.iloc[:,0], y = dist_resp.iloc[:,2])
    plt.title('Percentage of interested parties by {}'.format(i))
    plt.xlabel(i)
    plt.ylabel('Percentage of interested parties')
    plt.show()

# %% [markdown]
# ## 3.4 Relatório com o SweetViz

# %%
# report = sv.analyze(source = df3, target_feat = 'response')
# report.show_html()

# %%
df3.to_csv('data/df3.csv', index = False)

# %% [markdown]
# # 4.0 Preparação dos dados

# %% [markdown]
# ## 4.1 Separação em treino e validação

# %%
# lê os dados gravados para não precisar carregar toda a limpeza dos dados e análise exploratória
df41 = pd.read_csv('data/df3.csv')
df41.head()
# Out:
#    id  gender  age  driving_license  region_code  previously_insured  vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  vintage  response
# 0   1       1   44                1           28                   0            3               1         40454.0                    26      217         1
# 1   2       1   76                1            3                   0            2               0         33536.0                    26      183         0
# 2   3       1   47                1           28                   0            3               1         38294.0                    26       27         1
# 3   4       1   21                1           11                   1            1               0         28619.0                   152      203         0
# 4   5       0   29                1           41                   1            1               0         27496.0                   152       39         0

# %%
# separação entre features e label
x = df41.drop(['response'], axis = 1)
y = df41['response']

# precisa separar antes para que os dados de validação não vejam as transformações que serão feitas nos dados de treino
x_train, x_val, y_train, y_val = ms.train_test_split(x, y, test_size = 0.2, random_state = 42)

df4 = pd.concat([x_train, y_train], axis = 1)
df4.head()
# Out:
#             id  gender  age  driving_license  region_code  previously_insured  vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  vintage  response
# 332803  332804       0   39                1           15                   0            2               1         52906.0                    55      227         1
# 116248  116249       1   38                1           11                   0            2               1         23038.0                    26       29         0
# 255005  255006       1   22                1           30                   1            1               0         45318.0                   152      166         0
# 317474  317475       0   23                1           41                   1            1               0         29132.0                   151      277         0
# 344212  344213       1   56                1           48                   0            3               1          2630.0                   154      155         0

# %% [markdown]
# ## 4.2 Normalização

# %%
# ss = StandardScaler()
# df4['annual_premium'] = ss.fit_transform(df4[['annual_premium']].values)

# df4.head()

# %%
# annual_premium
df4['annual_premium'] = (df4['annual_premium'] - df4['annual_premium'].mean()) / df4['annual_premium'].std()

df4.head()
# Out:
#             id  gender  age  driving_license  region_code  previously_insured  vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  vintage  response
# 332803  332804       0   39                1           15                   0            2               1        1.294415                    55      227         1
# 116248  116249       1   38                1           11                   0            2               1       -0.436638                    26       29         0
# 255005  255006       1   22                1           30                   1            1               0        0.854639                   152      166         0
# 317474  317475       0   23                1           41                   1            1               0       -0.083449                   151      277         0
# 344212  344213       1   56                1           48                   0            3               1       -1.619419                   154      155         0

# %% [markdown]
# ## 4.3 Reescala

# %%
# mms_age = MinMaxScaler()
# mms_vintage = MinMaxScaler()
# df4['age'] = mms_age.fit_transform(df4[['age']].values)
# df4['vintage'] = mms_vintage.fit_transform(df4[['vintage']].values)

# df4.head()

# %%
# age and vintage
df4['age'] = (df4['age'] - df4['age'].min()) / (df4['age'].max() - df4['age'].min())
df4['vintage'] = (df4['vintage'] - df4['vintage'].min()) / (df4['vintage'].max() - df4['vintage'].min())

df4.head()
# Out:
#             id  gender       age  driving_license  region_code  previously_insured  vehicle_age  vehicle_damage  annual_premium  policy_sales_channel   vintage  response
# 332803  332804       0  0.292308                1           15                   0            2               1        1.294415                    55  0.750865         1
# 116248  116249       1  0.276923                1           11                   0            2               1       -0.436638                    26  0.065744         0
# 255005  255006       1  0.030769                1           30                   1            1               0        0.854639                   152  0.539792         0
# 317474  317475       0  0.046154                1           41                   1            1               0       -0.083449                   151  0.923875         0
# 344212  344213       1  0.553846                1           48                   0            3               1       -1.619419                   154  0.501730         0

# %% [markdown]
# ## 4.4 Encoding

# %%
# region_code - target encoder
rc_encoder = df4.groupby('region_code')['response'].mean()
df4.loc[:,'region_code'] = df4['region_code'].map(rc_encoder)

# policy_sales_channel - frequency encoder
psc_encoder = df4.groupby('policy_sales_channel').size()/len(df4)
df4.loc[:,'policy_sales_channel'] = df4['policy_sales_channel'].map(psc_encoder)

df4.head()
# Out:
#             id  gender       age  driving_license  region_code  previously_insured  vehicle_age  vehicle_damage  annual_premium  policy_sales_channel   vintage  response
# 332803  332804       0  0.292308                1     0.070151                   0            2               1        1.294415              0.003309  0.750865         1
# 116248  116249       1  0.276923                1     0.109796                   0            2               1       -0.436638              0.209638  0.065744         0
# 255005  255006       1  0.030769                1     0.074305                   1            1               0        0.854639              0.353472  0.539792         0
# 317474  317475       0  0.046154                1     0.122946                   1            1               0       -0.083449              0.010050  0.923875         0
# 344212  344213       1  0.553846                1     0.100978                   0            3               1       -1.619419              0.015901  0.501730         0

# %% [markdown]
# ## 4.5 Preparação dos dados de validação

# %%
x_val['annual_premium'] = (x_val['annual_premium'] - x_val['annual_premium'].mean()) / x_val['annual_premium'].std()

x_val['age'] = (x_val['age'] - x_val['age'].min()) / (x_val['age'].max() - x_val['age'].min())

x_val['vintage'] = (x_val['vintage'] - x_val['vintage'].min()) / (x_val['vintage'].max() - x_val['vintage'].min())

x_val.loc[:,'region_code'] = x_val['region_code'].map(rc_encoder)

x_val.loc[:,'policy_sales_channel'] = x_val['policy_sales_channel'].map(psc_encoder)

# para caso algum 'policy_sales_channel' ou 'region_code' não aparça na validação, preencher com 0
x_val = x_val.fillna(0)

# %% [markdown]
# # 5.0 Seleção de atributos

# %% [markdown]
# ## 5.1 Seleção por importância

# %%
# Separação entre features e label
x_train_select = df4.drop(['id', 'response'], axis = 1).values
y_train_select = y_train.values

# Treinando um modelo de random forest para selecionar as features
model_select = RandomForestClassifier(n_estimators = 100, random_state = 42, n_jobs = -1)
model_select.fit(x_train_select, y_train_select)

# Selecionando as features de maior importância através do modelo treinado
n_features = x_train_select.shape[1] # shape[1] -> quantidade de colunas, se fosse shape[0] -> quantidade de linhas
feature_names = [f"feature {i}" for i in range(n_features)]
importances = model_select.feature_importances_
forest_importances = pd.Series(importances, index = feature_names)

row_labels = {'feature 0': 'gender',
              'feature 1': 'age',
              'feature 2': 'driving_license',
              'feature 3': 'region_code',
              'feature 4': 'previously_insured',
              'feature 5': 'vehicle_age',
              'feature 6': 'vehicle_damage',
              'feature 7': 'annual_premium',
              'feature 8': 'policy_sales_channel',
              'feature 9': 'vintage'}

forest_importances.rename(index = row_labels, inplace = True)
df_forest_importances = pd.DataFrame(data = forest_importances).reset_index()
df_forest_importances.rename(columns = {'index': 'Features', 0: 'Relevância Percentual'}).sort_values(by = 'Relevância Percentual', ascending = False)
# Out:
#                Features  Relevância Percentual
# 9               vintage               0.282478
# 7        annual_premium               0.252189
# 1                   age               0.146168
# 3           region_code               0.094896
# 6        vehicle_damage               0.073483
# 8  policy_sales_channel               0.070491
# 4    previously_insured               0.050273
# 5           vehicle_age               0.016213
# 0                gender               0.013262
# 2       driving_license               0.000547

# %%
# Colunas selecionadas (>2% de importância):
cols_selected_mdi = ['vintage', 'annual_premium', 'age', 'region_code', 'vehicle_damage', 'policy_sales_channel', 'previously_insured']

x_train = df4.copy()

# %% [markdown]
# # 6.0 Modelagem

# %% [markdown]
# ## 6.1 KNN

# %%
knn_model = KNeighborsClassifier(n_neighbors = 5)

knn = cross_validation(x_train, y_train, x_val, y_val, 5, knn_model, verbose = False)
# Out:
# Precision Top K: 0.3273, Recall Top K: 0.0713
# Precision Top K: 0.3123, Recall Top K: 0.0673
# Precision Top K: 0.3408, Recall Top K: 0.0728
# Precision Top K: 0.3218, Recall Top K: 0.068
# Precision Top K: 0.3323, Recall Top K: 0.0722
#
# Precisão Top K Média: 0.32693653173413295, Recall Top K Média: 0.07030981962208545

# %% [markdown]
# ## 6.2 Logistic Regression

# %%
# classes balanceadas
lr_model = lm.LogisticRegression(n_jobs = -1, max_iter = 100, class_weight = 'balanced')

lr = cross_validation(x_train, y_train, x_val, y_val, 5, lr_model, verbose = False)
# Out:
# Precision Top K: 0.3123, Recall Top K: 0.066
# Precision Top K: 0.3088, Recall Top K: 0.0665
# Precision Top K: 0.2974, Recall Top K: 0.0631
# Precision Top K: 0.2784, Recall Top K: 0.0606
# Precision Top K: 0.2984, Recall Top K: 0.0639
#
# Precisão Top K Média: 0.2990504747626187, Recall Top K Média: 0.06399986683097537

# %% [markdown]
# ## 6.3 Random Forest

# %%
rf_model = RandomForestClassifier(n_estimators = 100, n_jobs = -1)

rf = cross_validation(x_train, y_train, x_val, y_val, 5, rf_model, verbose = False)
# Out:
# Precision Top K: 0.3708, Recall Top K: 0.0797
# Precision Top K: 0.3613, Recall Top K: 0.0775
# Precision Top K: 0.3633, Recall Top K: 0.0764
# Precision Top K: 0.3693, Recall Top K: 0.078
# Precision Top K: 0.3553, Recall Top K: 0.0756
#
# Precisão Top K Média: 0.3640179910044978, Recall Top K Média: 0.0774247683225234

# %% [markdown]
# ## 6.4 XGBoost

# %%
xgb_model = xgb.XGBClassifier(objective = 'binary:logistic', n_estimators = 100, nthread = -1)

xgb_ = cross_validation(x_train, y_train, x_val, y_val, 5, xgb_model, verbose = False)
# Out:
# Precision Top K: 0.4178, Recall Top K: 0.0896
# Precision Top K: 0.4168, Recall Top K: 0.0905
# Precision Top K: 0.4198, Recall Top K: 0.0899
# Precision Top K: 0.3998, Recall Top K: 0.0855
# Precision Top K: 0.4278, Recall Top K: 0.0909
#
# Precisão Top K Média: 0.416391804097951, Recall Top K Média: 0.08927088538755762

# %% [markdown]
# # 7.0 Tunagem de hiperparâmetros

# %% [markdown]
# ## 7.1 Randomized search

# %%
# param = {
#    'n_estimators': [100, 300, 500, 1000],
#    'max_depth': [1, 2, 3, 4, 5],
#    'subsample': [0.5, 0.7, 0.8],
#    'colsample_bytree': [0.5, 0.7, 0.8],
#    'scale_pos_weight': [1, 7]
#        }

# max_eval = 30 # irá pegar 30 conjuntos diferentes de parâmetros
# kfold = 5 # irá realizar 5 divisões no dataset para o cross-validation

# for i in range(max_eval):
#     hp = {k: random.sample(v, 1)[0] for k, v in param.items()}
#     print(f'{hp}\n')
   
#     # como a melhor performance obitda foi com o xgb, a tunagem dos parâmetros ocorrerá com ele
#     xgb_tun = xgb.XGBClassifier(objective = 'binary:logistic',
#                                  n_estimators = hp['n_estimators'], 
#                                  max_depth = hp['max_depth'], 
#                                  subsample = hp['subsample'],
#                                  colsample_bytree = hp['colsample_bytree'],
#                                  scale_pos_weight = hp['scale_pos_weight'])
    
#     result = cross_validation(x_train, y_train, x_val, y_val, kfold, xgb_tun, verbose = False)
# Out:
# {'n_estimators': 300, 'max_depth': 2, 'subsample': 0.8, 'colsample_bytree': 0.7, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4373, Recall Top K: 0.0957
# Precision Top K: 0.4158, Recall Top K: 0.0885
# Precision Top K: 0.4388, Recall Top K: 0.0938
# Precision Top K: 0.4423, Recall Top K: 0.0945
# Precision Top K: 0.4208, Recall Top K: 0.0911
#
# Precisão Top K Média: 0.43098450774612695, Recall Top K Média: 0.09272252266896328
#
# {'n_estimators': 1000, 'max_depth': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4103, Recall Top K: 0.0874
# Precision Top K: 0.4138, Recall Top K: 0.0886
# Precision Top K: 0.4233, Recall Top K: 0.0898
# Precision Top K: 0.4028, Recall Top K: 0.087
# Precision Top K: 0.4368, Recall Top K: 0.0938
#
# Precisão Top K Média: 0.41739130434782606, Recall Top K Média: 0.08929534154647992
#
# {'n_estimators': 1000, 'max_depth': 5, 'subsample': 0.8, 'colsample_bytree': 0.5, 'scale_pos_weight': 7}
#
# Precision Top K: 0.3803, Recall Top K: 0.0817
# Precision Top K: 0.4068, Recall Top K: 0.0869
# Precision Top K: 0.3878, Recall Top K: 0.082
# Precision Top K: 0.4008, Recall Top K: 0.085
# Precision Top K: 0.3938, Recall Top K: 0.0824
#
# Precisão Top K Média: 0.39390304847576213, Recall Top K Média: 0.08360469851290601
#
# {'n_estimators': 1000, 'max_depth': 4, 'subsample': 0.5, 'colsample_bytree': 0.8, 'scale_pos_weight': 7}
#
# Precision Top K: 0.3933, Recall Top K: 0.0838
# Precision Top K: 0.3928, Recall Top K: 0.0854
# Precision Top K: 0.3758, Recall Top K: 0.0804
# Precision Top K: 0.3888, Recall Top K: 0.0843
# Precision Top K: 0.3853, Recall Top K: 0.0816
#
# Precisão Top K Média: 0.3872063968015992, Recall Top K Média: 0.08309086421611335
#
# {'n_estimators': 100, 'max_depth': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4248, Recall Top K: 0.0906
# Precision Top K: 0.4203, Recall Top K: 0.0905
# Precision Top K: 0.3943, Recall Top K: 0.0848
# Precision Top K: 0.4203, Recall Top K: 0.0896
# Precision Top K: 0.4233, Recall Top K: 0.0903
#
# Precisão Top K Média: 0.416591704147926, Recall Top K Média: 0.08917696723951947
#
# {'n_estimators': 1000, 'max_depth': 2, 'subsample': 0.7, 'colsample_bytree': 0.5, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4028, Recall Top K: 0.0868
# Precision Top K: 0.4103, Recall Top K: 0.0881
# Precision Top K: 0.4068, Recall Top K: 0.0886
# Precision Top K: 0.4223, Recall Top K: 0.0903
# Precision Top K: 0.3863, Recall Top K: 0.0829
#
# Precisão Top K Média: 0.40569715142428786, Recall Top K Média: 0.08735342950715992
#
# {'n_estimators': 1000, 'max_depth': 3, 'subsample': 0.8, 'colsample_bytree': 0.7, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4078, Recall Top K: 0.0872
# Precision Top K: 0.4298, Recall Top K: 0.0922
# Precision Top K: 0.4158, Recall Top K: 0.0891
# Precision Top K: 0.3978, Recall Top K: 0.0851
# Precision Top K: 0.4048, Recall Top K: 0.0848
#
# Precisão Top K Média: 0.41119440279860064, Recall Top K Média: 0.08767809712304915
#
# {'n_estimators': 500, 'max_depth': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4263, Recall Top K: 0.0919
# Precision Top K: 0.4178, Recall Top K: 0.0906
# Precision Top K: 0.4113, Recall Top K: 0.0881
# Precision Top K: 0.4033, Recall Top K: 0.0875
# Precision Top K: 0.4268, Recall Top K: 0.0916
#
# Precisão Top K Média: 0.4170914542728636, Recall Top K Média: 0.08991844441385663
#
# {'n_estimators': 300, 'max_depth': 2, 'subsample': 0.7, 'colsample_bytree': 0.7, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4253, Recall Top K: 0.091
# Precision Top K: 0.4403, Recall Top K: 0.0939
# Precision Top K: 0.4308, Recall Top K: 0.0921
# Precision Top K: 0.4318, Recall Top K: 0.0923
# Precision Top K: 0.4333, Recall Top K: 0.091
#
# Precisão Top K Média: 0.4322838580709645, Recall Top K Média: 0.09207099381870236
#
# {'n_estimators': 300, 'max_depth': 5, 'subsample': 0.5, 'colsample_bytree': 0.5, 'scale_pos_weight': 7}
#
# Precision Top K: 0.3973, Recall Top K: 0.0846
# Precision Top K: 0.3933, Recall Top K: 0.0835
# Precision Top K: 0.4058, Recall Top K: 0.0875
# Precision Top K: 0.4023, Recall Top K: 0.0862
# Precision Top K: 0.4208, Recall Top K: 0.089
#
# Precisão Top K Média: 0.40389805097451276, Recall Top K Média: 0.08617809030276288
#
# {'n_estimators': 300, 'max_depth': 2, 'subsample': 0.8, 'colsample_bytree': 0.5, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4293, Recall Top K: 0.0915
# Precision Top K: 0.4483, Recall Top K: 0.0953
# Precision Top K: 0.4198, Recall Top K: 0.0899
# Precision Top K: 0.4318, Recall Top K: 0.0928
# Precision Top K: 0.4258, Recall Top K: 0.0909
#
# Precisão Top K Média: 0.43098450774612695, Recall Top K Média: 0.09205339097872846
#
# {'n_estimators': 500, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.5, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4193, Recall Top K: 0.0903
# Precision Top K: 0.4213, Recall Top K: 0.0905
# Precision Top K: 0.4373, Recall Top K: 0.0939
# Precision Top K: 0.4053, Recall Top K: 0.087
# Precision Top K: 0.4128, Recall Top K: 0.0883
#
# Precisão Top K Média: 0.4191904047976013, Recall Top K Média: 0.09001296998374296
#
# {'n_estimators': 100, 'max_depth': 1, 'subsample': 0.5, 'colsample_bytree': 0.8, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4103, Recall Top K: 0.088
# Precision Top K: 0.4143, Recall Top K: 0.0887
# Precision Top K: 0.3953, Recall Top K: 0.0859
# Precision Top K: 0.4323, Recall Top K: 0.0923
# Precision Top K: 0.4308, Recall Top K: 0.0929
#
# Precisão Top K Média: 0.41659170414792596, Recall Top K Média: 0.08954602686708499
#
# {'n_estimators': 100, 'max_depth': 3, 'subsample': 0.5, 'colsample_bytree': 0.5, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4113, Recall Top K: 0.0883
# Precision Top K: 0.4183, Recall Top K: 0.09
# Precision Top K: 0.4273, Recall Top K: 0.0915
# Precision Top K: 0.4343, Recall Top K: 0.093
# Precision Top K: 0.4233, Recall Top K: 0.0909
#
# Precisão Top K Média: 0.4228885557221389, Recall Top K Média: 0.09076090541807016
#
# {'n_estimators': 100, 'max_depth': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4233, Recall Top K: 0.0893
# Precision Top K: 0.4278, Recall Top K: 0.0912
# Precision Top K: 0.4148, Recall Top K: 0.0892
# Precision Top K: 0.4193, Recall Top K: 0.0907
# Precision Top K: 0.4078, Recall Top K: 0.0872
#
# Precisão Top K Média: 0.4185907046476761, Recall Top K Média: 0.0895122506327969
#
# {'n_estimators': 300, 'max_depth': 3, 'subsample': 0.5, 'colsample_bytree': 0.5, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4248, Recall Top K: 0.0909
# Precision Top K: 0.4033, Recall Top K: 0.0866
# Precision Top K: 0.4163, Recall Top K: 0.0891
# Precision Top K: 0.4138, Recall Top K: 0.0888
# Precision Top K: 0.4208, Recall Top K: 0.0885
#
# Precisão Top K Média: 0.415792103948026, Recall Top K Média: 0.08877249959042972
#
# {'n_estimators': 1000, 'max_depth': 3, 'subsample': 0.8, 'colsample_bytree': 0.7, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4223, Recall Top K: 0.0891
# Precision Top K: 0.4008, Recall Top K: 0.087
# Precision Top K: 0.3893, Recall Top K: 0.0843
# Precision Top K: 0.4043, Recall Top K: 0.088
# Precision Top K: 0.3858, Recall Top K: 0.0836
#
# Precisão Top K Média: 0.40049975012493755, Recall Top K Média: 0.08641393403823558
#
# {'n_estimators': 500, 'max_depth': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'scale_pos_weight': 7}
#
# Precision Top K: 0.3873, Recall Top K: 0.0833
# Precision Top K: 0.3788, Recall Top K: 0.0804
# Precision Top K: 0.3928, Recall Top K: 0.0839
# Precision Top K: 0.3998, Recall Top K: 0.0855
# Precision Top K: 0.4183, Recall Top K: 0.0883
#
# Precisão Top K Média: 0.39540229885057476, Recall Top K Média: 0.08426631887509772
#
# {'n_estimators': 300, 'max_depth': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4148, Recall Top K: 0.0893
# Precision Top K: 0.4223, Recall Top K: 0.092
# Precision Top K: 0.4178, Recall Top K: 0.0901
# Precision Top K: 0.4228, Recall Top K: 0.0899
# Precision Top K: 0.4148, Recall Top K: 0.0889
#
# Precisão Top K Média: 0.4184907546226887, Recall Top K Média: 0.09005311187582116
#
# {'n_estimators': 1000, 'max_depth': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4128, Recall Top K: 0.0896
# Precision Top K: 0.4228, Recall Top K: 0.0901
# Precision Top K: 0.4118, Recall Top K: 0.0875
# Precision Top K: 0.4183, Recall Top K: 0.0887
# Precision Top K: 0.4123, Recall Top K: 0.088
#
# Precisão Top K Média: 0.41559220389805096, Recall Top K Média: 0.0887834587749446
#
# {'n_estimators': 500, 'max_depth': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4253, Recall Top K: 0.092
# Precision Top K: 0.4148, Recall Top K: 0.0893
# Precision Top K: 0.4313, Recall Top K: 0.091
# Precision Top K: 0.4203, Recall Top K: 0.0901
# Precision Top K: 0.4098, Recall Top K: 0.087
#
# Precisão Top K Média: 0.42028985507246375, Recall Top K Média: 0.08988228540508052
#
# {'n_estimators': 500, 'max_depth': 5, 'subsample': 0.8, 'colsample_bytree': 0.5, 'scale_pos_weight': 1}
#
# Precision Top K: 0.3993, Recall Top K: 0.0856
# Precision Top K: 0.3888, Recall Top K: 0.0835
# Precision Top K: 0.3833, Recall Top K: 0.0835
# Precision Top K: 0.4158, Recall Top K: 0.0882
# Precision Top K: 0.3903, Recall Top K: 0.0832
#
# Precisão Top K Média: 0.3955022488755622, Recall Top K Média: 0.08480547746038461
#
# {'n_estimators': 1000, 'max_depth': 3, 'subsample': 0.8, 'colsample_bytree': 0.7, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4083, Recall Top K: 0.0876
# Precision Top K: 0.4188, Recall Top K: 0.0904
# Precision Top K: 0.4273, Recall Top K: 0.0901
# Precision Top K: 0.4153, Recall Top K: 0.0898
# Precision Top K: 0.4133, Recall Top K: 0.0895
#
# Precisão Top K Média: 0.416591704147926, Recall Top K Média: 0.08947202474018345
#
# {'n_estimators': 1000, 'max_depth': 2, 'subsample': 0.8, 'colsample_bytree': 0.5, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4193, Recall Top K: 0.0908
# Precision Top K: 0.4048, Recall Top K: 0.0872
# Precision Top K: 0.4193, Recall Top K: 0.0902
# Precision Top K: 0.4373, Recall Top K: 0.0916
# Precision Top K: 0.4383, Recall Top K: 0.0927
#
# Precisão Top K Média: 0.42378810594702643, Recall Top K Média: 0.09049361428819797
#
# {'n_estimators': 300, 'max_depth': 4, 'subsample': 0.7, 'colsample_bytree': 0.7, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4273, Recall Top K: 0.0912
# Precision Top K: 0.4228, Recall Top K: 0.0907
# Precision Top K: 0.4403, Recall Top K: 0.0931
# Precision Top K: 0.3998, Recall Top K: 0.0867
# Precision Top K: 0.4123, Recall Top K: 0.0899
#
# Precisão Top K Média: 0.42048975512243886, Recall Top K Média: 0.09031670040534459
#
# {'n_estimators': 100, 'max_depth': 1, 'subsample': 0.5, 'colsample_bytree': 0.7, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4048, Recall Top K: 0.0865
# Precision Top K: 0.4003, Recall Top K: 0.0859
# Precision Top K: 0.4273, Recall Top K: 0.0914
# Precision Top K: 0.4113, Recall Top K: 0.0883
# Precision Top K: 0.4398, Recall Top K: 0.094
#
# Precisão Top K Média: 0.4166916541729135, Recall Top K Média: 0.08920769370672403
#
# {'n_estimators': 1000, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.7, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4323, Recall Top K: 0.0921
# Precision Top K: 0.4068, Recall Top K: 0.0879
# Precision Top K: 0.4068, Recall Top K: 0.0878
# Precision Top K: 0.4103, Recall Top K: 0.0882
# Precision Top K: 0.4143, Recall Top K: 0.0894
#
# Precisão Top K Média: 0.4140929535232384, Recall Top K Média: 0.08905685541500835
#
# {'n_estimators': 1000, 'max_depth': 4, 'subsample': 0.8, 'colsample_bytree': 0.7, 'scale_pos_weight': 7}
#
# Precision Top K: 0.4153, Recall Top K: 0.0893
# Precision Top K: 0.4113, Recall Top K: 0.0875
# Precision Top K: 0.4113, Recall Top K: 0.0878
# Precision Top K: 0.4008, Recall Top K: 0.0858
# Precision Top K: 0.4093, Recall Top K: 0.088
#
# Precisão Top K Média: 0.40959520239880065, Recall Top K Média: 0.08765743700184056
#
# {'n_estimators': 1000, 'max_depth': 1, 'subsample': 0.5, 'colsample_bytree': 0.7, 'scale_pos_weight': 1}
#
# Precision Top K: 0.4368, Recall Top K: 0.0932
# Precision Top K: 0.4128, Recall Top K: 0.0878
# Precision Top K: 0.4128, Recall Top K: 0.0871
# Precision Top K: 0.4158, Recall Top K: 0.0894
# Precision Top K: 0.4128, Recall Top K: 0.0885
#
# Precisão Top K Média: 0.4181909045477261, Recall Top K Média: 0.08922244528232823
#
# {'n_estimators': 500, 'max_depth': 4, 'subsample': 0.7, 'colsample_bytree': 0.8, 'scale_pos_weight': 7}
#
# Precision Top K: 0.3933, Recall Top K: 0.0848
# Precision Top K: 0.4103, Recall Top K: 0.089
# Precision Top K: 0.4053, Recall Top K: 0.0869
# Precision Top K: 0.4178, Recall Top K: 0.0896
# Precision Top K: 0.4078, Recall Top K: 0.0881
#
# Precisão Top K Média: 0.4068965517241379, Recall Top K Média: 0.08766425698384149

# %% [markdown]
# ## 7.2 Generalização

# %%
# instanciando o modelo final com os parâmetros tunados
xgb_final = xgb.XGBClassifier(objective = 'binary:logistic',
                              n_estimators = 300,
                              max_depth = 2,
                              subsample = 0.7,
                              colsample_bytree = 0.7,
                              scale_pos_weight = 7,
                              nthread = -1)

# modelo final com o cross-validation
df_final = cross_validation(x_train, y_train, x_val, y_val, 5, xgb_final, verbose = False)
# Out:
# Precision Top K: 0.4113, Recall Top K: 0.0897
# Precision Top K: 0.4188, Recall Top K: 0.0908
# Precision Top K: 0.4323, Recall Top K: 0.0915
# Precision Top K: 0.4178, Recall Top K: 0.0895
# Precision Top K: 0.4153, Recall Top K: 0.0882
#
# Precisão Top K Média: 0.4190904547726137, Recall Top K Média: 0.08994170352629936

# %%
df_final.head()
# Out:
#             id  gender       age  driving_license  region_code  previously_insured  vehicle_age  vehicle_damage  annual_premium  policy_sales_channel   vintage  response     score
# 222777  222778       0  0.415385                1     0.122946                   0            2               1        4.429701              0.209638  0.460208         1  0.915647
# 272744  272745       1  0.246154                1     0.186579                   0            2               1       15.288371              0.193934  0.415225         0  0.915293
# 102293  102294       1  0.353846                1     0.186579                   0            3               1       17.724518              0.209638  0.660900         1  0.912375
# 7349      7350       1  0.461538                1     0.186579                   0            2               1        4.485514              0.209638  0.629758         1  0.898579
# 365312  365313       1  0.292308                1     0.186579                   0            2               1        6.355141              0.209638  0.380623         0  0.896871

# %% [markdown]
# # 8.0 Resultados de negócio

# %% [markdown]
# ## 8.1 Curvas de ganho e lift

# %%
df_test = df_final.copy()

# porcentagem de interessados
df_test['real_cum'] = df_test['response'].cumsum() 
df_test['real_cum_perc'] = 100*df_test['real_cum']/df_test['response'].sum()

# porcentagem da base
df_test['base'] = range(1, len(df_test)+1)
df_test['base_cum_perc'] = 100*df_test['base']/len(df_test)

# modelo baseline
df_test['baseline'] = df_test['base_cum_perc']

# %%
df_test.head()
# Out:
#             id  gender       age  driving_license  region_code  previously_insured  vehicle_age  vehicle_damage  annual_premium  policy_sales_channel   vintage  response     score  real_cum  real_cum_perc  base  base_cum_perc  baseline
# 222777  222778       0  0.415385                1     0.122946                   0            2               1        4.429701              0.209638  0.460208         1  0.915647         1       0.010619     1       0.001312  0.001312
# 272744  272745       1  0.246154                1     0.186579                   0            2               1       15.288371              0.193934  0.415225         0  0.915293         1       0.010619     2       0.002624  0.002624
# 102293  102294       1  0.353846                1     0.186579                   0            3               1       17.724518              0.209638  0.660900         1  0.912375         2       0.021238     3       0.003936  0.003936
# 7349      7350       1  0.461538                1     0.186579                   0            2               1        4.485514              0.209638  0.629758         1  0.898579         3       0.031857     4       0.005248  0.005248
# 365312  365313       1  0.292308                1     0.186579                   0            2               1        6.355141              0.209638  0.380623         0  0.896871         3       0.031857     5       0.006560  0.006560

# %%
# curva ganho
sns.lineplot(x = 'base_cum_perc', y = 'real_cum_perc', data = df_test)
sns.lineplot(x = 'base_cum_perc', y = 'baseline', data = df_test)
# Out:
# <AxesSubplot: xlabel='base_cum_perc', ylabel='real_cum_perc'>

# %%
# curva lift
df_test['lift'] = df_test['real_cum_perc']/df_test['base_cum_perc']
sns.lineplot(x = 'base_cum_perc', y = 'lift', data = df_test)
# Out:
# <AxesSubplot: xlabel='base_cum_perc', ylabel='lift'>

# %% [markdown]
# ## 8.2 Curva ROI

# %%
df_roi = df_test.copy()

# criando 10 buckets/bins para agrupar os clientes
df_roi['bucket'] = df_roi['score'].apply(lambda x: 0.9 if x >= 0.90 else 
                                                           0.8 if ( x >= 0.80) & ( x <= 0.90 ) else 
                                                           0.7 if ( x >= 0.70) & ( x <= 0.80 ) else 
                                                           0.6 if ( x >= 0.60) & ( x <= 0.70 ) else 
                                                           0.5 if ( x >= 0.50) & ( x <= 0.60 ) else 
                                                           0.4 if ( x >= 0.40) & ( x <= 0.50 ) else 
                                                           0.3 if ( x >= 0.30) & ( x <= 0.40 ) else 
                                                           0.2 if ( x >= 0.20) & ( x <= 0.30 ) else 
                                                           0.1 if ( x >= 0.10) & ( x <= 0.20 ) else 0.01)

# agrupando os clientes em buckets
df_roi = df_roi[['score', 'bucket']].groupby('bucket').agg({'min', 'count'}).reset_index()
df_roi.columns = df_roi.columns.droplevel() # remove o nível superior do cabeçalho (bucket e score), pois a função agg. cria mais um nível de cabeçalho
df_roi.columns = ['bucket', 'clients', 'min_score']
df_roi.columns = ['bucket', 'min_score', 'clients'] # quando dropa o level as colunas clients e min_score ficam invertidas, por isso precisa reverter

# %%
gross_revenue_per_converted_client = 40 # simula uma receita bruta de 40 dólares por cliente convertido
client_cost = 4 # simula um custo de 4 dólares por cliente
# * Estes valores dependem muito da compreensão do negócio. Precisa ter uma noção de como é o CAC e de como é o LTV do negócio

# calcula a receita bruta e o custo
df_roi['bucket_gross_revenue'] = gross_revenue_per_converted_client * df_roi['clients'] * df_roi['min_score']
# neste cálculo, dando um exemplo para o bucket 0.1, considera-se que a cada 10 clientes 1 seja convertido, por isso ocorre a multiplicação pelo min_score
df_roi['bucket_cost'] = client_cost * df_roi['clients']

# # calcula qual o percentual da base alcançado após cada bucket alcançado
df_roi = df_roi.sort_values(by = 'bucket', ascending = False)
df_roi['base'] = df_roi['clients'].cumsum() / df_roi['clients'].sum()

# receita líquida do bucket
df_roi['bucket_revenue'] = df_roi['bucket_gross_revenue'] - df_roi['bucket_cost']

# receita líquida acumulada
df_roi['accumulated_revenue'] = df_roi['bucket_revenue'].cumsum()

df_roi
# Out:
#    bucket  min_score  clients  bucket_gross_revenue  bucket_cost      base  bucket_revenue  accumulated_revenue
# 9    0.90   0.912375        3            109.485018           12  0.000039       97.485018            97.485018
# 8    0.80   0.800001     5224         167168.164406        20896  0.068576   146272.164406        146369.649424
# 7    0.70   0.700015    14612         409144.772139        58448  0.260279   350696.772139        497066.421563
# 6    0.60   0.600018     6409         153820.498505        25636  0.344363   128184.498505        625250.920067
# 5    0.50   0.500018     4094          81882.889214        16376  0.398074    65506.889214        690757.809281
# 4    0.40   0.400020     3395          54322.716451        13580  0.442615    40742.716451        731500.525732
# 3    0.30   0.300038     2099          25191.203821         8396  0.470153    16795.203821        748295.729552
# 2    0.20   0.200006     2033          16264.476465         8132  0.496825     8132.476465        756428.206017
# 1    0.10   0.100026     2971          11887.123078        11884  0.535803        3.123078        756431.329095
# 0    0.01   0.000067    35382             94.997336       141528  1.000000  -141433.002664        614998.326432

# %%
roi_curve = df_roi[df_roi['min_score'] >= 0.1]
sns.lineplot(x = 'base', y = 'accumulated_revenue', data = df_roi)
# Out:
# <AxesSubplot: xlabel='base', ylabel='accumulated_revenue'>

# %% [markdown]
# # 9.0 Modelo em produção

# %% [markdown]
# ## 9.1 Armazenamento dos parâmetros e do modelo

# %%
# Parâmetros da preparação dos dados
pickle.dump(rc_encoder, open('parameter/region_code.pkl', 'wb'))
pickle.dump(psc_encoder, open('parameter/policy_sales_channel.pkl', 'wb'))

# Modelo final
pickle.dump(xgb_final, open('model/health_insurance_model.pkl', 'wb'))

# %% [markdown]
# ## 9.2 Criação da classe HealthInsurance local

# %%
import pickle
import inflection
import numpy  as np
import pandas as pd

class HealthInsurance():
    
    def __init__(self):
        self.home_path = 'C:\\Users\\micro\\Desktop\\repos\\3_ciclo_intermediario\\7_health_insurance_cross_sell\\'
        self.region_code = pickle.load(open(self.home_path + 'parameter\\region_code.pkl', 'rb'))
        self.policy_sales_channel = pickle.load(open(self.home_path + 'parameter\\policy_sales_channel.pkl', 'rb'))
        
    def data_cleaning(self, df1):
        cols_old = ['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
       'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
       'Policy_Sales_Channel', 'Vintage']
        
        # renomeando colunas
        snakecase = lambda x: inflection.underscore(x)
        cols_new = list(map(snakecase, cols_old))
        df1.columns = cols_new
        
        # alterando dados float64 para diminuir o tamanho do dataset
        df1['region_code'] = df1['region_code'].astype('int64')
        df1['policy_sales_channel'] = df1['policy_sales_channel'].astype('int64')
        df1['annual_premium'] = df1['annual_premium'].astype('float32')

        # transformando atributos categóricos em numéricos
        df1['gender'] = df1['gender'].apply(lambda x: 0 if x == 'Female' else 1)
        df1['vehicle_damage'] = df1['vehicle_damage'].apply(lambda x: 0 if x == 'No' else 1)
        df1['vehicle_age'] = df1['vehicle_age'].apply(lambda x: 1 if (x == '< 1 Year') else 
                                                      2 if (x == '1-2 Year') else 
                                                      3 if (x == '> 2 Years') else x)
        
        return df1
        
    def data_preparation(self, df2):
        df2['annual_premium'] = (df2['annual_premium'] - df2['annual_premium'].mean()) / df2['annual_premium'].std()
        df2['age'] = (df2['age'] - df2['age'].min()) / (df2['age'].max() - df2['age'].min())
        df2['vintage'] = (df2['vintage'] - df2['vintage'].min()) / (df2['vintage'].max() - df2['vintage'].min())
        df2.loc[:,'region_code'] = df2['region_code'].map(self.region_code)
        df2.loc[:,'policy_sales_channel'] = df2['policy_sales_channel'].map(self.policy_sales_channel)
        # para caso algum 'policy_sales_channel' ou 'region_code' não aparça na validação, preencher com 0
        df2 = df2.fillna(0)
        cols_selected_mdi = ['vintage', 'annual_premium', 'age', 'region_code', 'vehicle_damage', 'policy_sales_channel', 'previously_insured']
        df2 = df2[cols_selected_mdi]
        
        return df2

    def get_prediction(self, xgb_final, df_original, df_prep):
        predicao = xgb_final.predict_proba(df_prep)
        df_original['score'] = predicao[:,1].tolist()
        
        return df_original.to_json(orient='records')

# %% [markdown]
# ## 9.3 Criação da API local

# %%
# import pickle
# import os
# import pandas as pd
# import numpy  as np
# from flask import Flask, request, Response

# path = 'C:\\Users\\micro\\Desktop\\repos\\3_ciclo_intermediario\\7_health_insurance_cross_sell\\'
# model = pickle.load(open(path + 'model\\health_insurance_model.pkl', 'rb'))

# app = Flask(__name__)

# @app.route('/healthinsurance/predict', methods=['POST'])
# def health_insurance_predict():
#     test_json = request.get_json()

#     if test_json:
#         if isinstance(test_json, dict):
#             test_raw = pd.DataFrame(test_json, index=[0])

#         else:
#             test_raw = pd.DataFrame(test_json, columns=test_json[0].keys())

#         pipeline = HealthInsurance()

#         df1 = pipeline.data_cleaning(test_raw)

#         df2 = pipeline.data_preparation(df1)

#         df_response = pipeline.get_prediction(model, test_raw, df2)

#         return df_response

#     else:
#         return Response('{}', status=200, mimetype='application/json')

# if __name__ == '__main__':
#     app.run('127.0.0.1')
#     # port = os.environ.get('PORT', 5000)
#     # app.run(host = '0.0.0.0', port = port, debug = True)

# %% [markdown]
# ## 9.4 Teste da API local

# %%
import pickle
import inflection
# import os
import math
import datetime
import pandas as pd
import numpy  as np
from flask import Flask, request, Response
import requests

d1 = pd.read_csv('\\Users\\micro\\Desktop\\repos\\3_ciclo_intermediario\\7_health_insurance_cross_sell\\data\\test.csv')

# converte o dataframe em json para fazer a comunicação entre os sistemas
data = json.dumps(d1.to_dict(orient = 'records'))

# %%
# chamada em API
url = 'http://127.0.0.1:5000/healthinsurance/predict'
# url = 'https://health-insurance-api-5z78.onrender.com/healthinsurance/predict'
header = {'Content-type': 'application/json'} 
data = data

# %%
r = requests.post(url, data = data, headers = header) # post: precisa enviar algum dado para requerir
print('Status Code {}'.format(r.status_code)) # para ver se a requisição é válida ou não

# %%
# pega o json da requisição e converte em dataframe
d2 = pd.DataFrame(r.json(), columns = r.json()[0].keys())

# ordenando a base de acordo com a propensão de compra de cada cliente
d2.sort_values('score', ascending = False).head()

# %%
# gerando um csv com as predições
d2.to_csv('predictions.csv', index = False)
